# %% [markdown]
# # 01_2.Formula 1 Qualifying Data Collection

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import time
start = time.time()

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
import requests
import bs4
from bs4 import BeautifulSoup
import time

# %%
qualifying_results = pd.read_csv('./data/qualifying.csv')

# %%
print(qualifying_results.shape)
# Out:
# (435, 6)

# %%
len(qualifying_results)
# Out:
# 435

# %%
qualifying_results.head()
# Out:
#    grid_position            driver_name                    car  \
# 0              1   Max  Verstappen  VER  Red Bull Racing Honda
# 1              2   Lewis  Hamilton  HAM               Mercedes
# 2              3  Valtteri  Bottas  BOT               Mercedes
# 3              4  Charles  Leclerc  LEC                Ferrari
# 4              5     Pierre  Gasly  GAS       AlphaTauri Honda
#
#   qualifying_time  season  round
# 0        1:28.997    2021      1
# 1        1:29.385    2021      1
# 2        1:29.586    2021      1
# 3        1:29.678    2021      1
# 4        1:29.809    2021      1

# %%
qualifying_results.tail()
# Out:
#      grid_position             driver_name                        car  \
# 430             15  Sebastian  Vettel  VET      Aston Martin Mercedes
# 431             16   Nicholas  Latifi  LAT          Williams Mercedes
# 432             17    George  Russell  RUS          Williams Mercedes
# 433             18    Kimi  Räikkönen  RAI  Alfa Romeo Racing Ferrari
# 434             19   Mick  Schumacher  MSC               Haas Ferrari
#
#     qualifying_time  season  round
# 430        1:24.305    2021     22
# 431        1:24.338    2021     22
# 432        1:24.423    2021     22
# 433        1:24.779    2021     22
# 434        1:24.906    2021     22

# %% [markdown]
# ## Feature Distributions

# %%
qualifying_results.hist()
# Out:
# array([[<AxesSubplot:title={'center':'grid_position'}>,
#         <AxesSubplot:title={'center':'season'}>],
#        [<AxesSubplot:title={'center':'round'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## Feature-Feature Relationships

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(qualifying_results, alpha=0.2, figsize=(30, 30), diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='grid_position', ylabel='grid_position'>,
#         <AxesSubplot:xlabel='season', ylabel='grid_position'>,
#         <AxesSubplot:xlabel='round', ylabel='grid_position'>],
#        [<AxesSubplot:xlabel='grid_position', ylabel='season'>,
#         <AxesSubplot:xlabel='season', ylabel='season'>,
#         <AxesSubplot:xlabel='round', ylabel='season'>],
#        [<AxesSubplot:xlabel='grid_position', ylabel='round'>,
#         <AxesSubplot:xlabel='season', ylabel='round'>,
#         <AxesSubplot:xlabel='round', ylabel='round'>]], dtype=object)

# %%
end = time.time()

# %%
import datetime
str(datetime.timedelta(seconds=(end - start)))
# Out:
# '0:00:04.056510'

# %%
print(str(end - start)+" seconds")
# Out:
# 4.0565104484558105 seconds
